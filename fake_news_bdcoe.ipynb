# %% [markdown]
# <a href="https://colab.research.google.com/github/yadavanushka266/Fake_News_Prediction_System_BDCOE/blob/main/fake_news_bdcoe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Fake News Detection System**

# %% [markdown]
# The rise of digital media has made it easier than ever to spread false or misleading information. This Fake News Detection System uses machine learning to classify news articles as real or fake, helping users identify unreliable content.

# %% [markdown]
# **Introduction**

# %% [markdown]
# In today’s digital age, misinformation spreads quickly across social media and news platforms, often blurring the line between fact and fiction. The increasing volume of fake news poses a serious threat to public opinion, trust, and decision-making. To address this challenge, we present a Fake News Detection System that uses machine learning to classify news content as real or fake. The system analyzes textual patterns, linguistic features, and contextual clues to assess the credibility of an article.

# %% [markdown]
# **Important Algorithms Used**
#
# 1.Linear Regression
#
# 2.Decision Tree Classifier
#
# 3.Gradient Booster Classifier
#
# 4.Random Forest Classifier

# %% [markdown]
# **Importing Standard Libraries**
#
# 1.Numpy
#
# 2.Pandas
#
# 3.Matplotlib
#
# 4.Seaborn
#
# 5.Scikit-Learn
#
# 6.Re

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
import re
import string

# %% [markdown]
# **Loading the Fake News Dataset**

# %%
import csv
fake=pd.read_csv('/content/Fake.csv')

# %% [markdown]
# **Loading the True News Dataset**

# %%
import csv
true=pd.read_csv('/content/True.csv')

# %% [markdown]
# **Let's look the data in the columns at front**

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %% [markdown]
# **Let's look the data in the columns at the back**

# %%
fake.tail()
# Out:
#                                                    title  \
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 23476  21st Century Wire says As 21WIRE reported earl...  Middle-east
# 23477  21st Century Wire says It s a familiar theme. ...  Middle-east
# 23478  Patrick Henningsen  21st Century WireRemember ...  Middle-east
# 23479  21st Century Wire says Al Jazeera America will...  Middle-east
# 23480  21st Century Wire says As 21WIRE predicted in ...  Middle-east
#
#                    date
# 23476  January 16, 2016
# 23477  January 16, 2016
# 23478  January 15, 2016
# 23479  January 14, 2016
# 23480  January 12, 2016

# %%
true.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date
# 21412  August 22, 2017
# 21413  August 22, 2017
# 21414  August 22, 2017
# 21415  August 22, 2017
# 21416  August 22, 2017

# %% [markdown]
# **Labelling the real news and fake news**

# %%
fake['class']=0
true['class']=1

# %% [markdown]
# **Shape of the Dataset**

# %%
fake.shape
# Out:
# (23481, 5)

# %%
true.shape
# Out:
# (21417, 5)

# %%
fake.shape,true.shape
# Out:
# ((23481, 5), (21417, 5))

# %% [markdown]
# **Tokenizing the fake Data**

# %%
fake_manual_testing=fake.tail(10)
for i in range(23480,23470,-1):
  fake.drop([i],axis=0,inplace=True)

# %% [markdown]
# **Tokenizing the real Data**

# %%
true_manual_testing=true.tail(10)
for i in range(21416,21406,-1):
  true.drop([i],axis=0,inplace=True)

# %% [markdown]
# **Checking the Shape of the datasets**

# %%
fake.shape,true.shape
# Out:
# ((23471, 5), (21407, 5))

# %% [markdown]
# **Labelling the data **

# %%
fake_manual_testing['class']=0
true_manual_testing['class']=1
# Out:
# /tmp/ipython-input-1287159230.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fake_manual_testing['class']=0
# /tmp/ipython-input-1287159230.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   true_manual_testing['class']=1

# %% [markdown]
# **Checking the front columns of the new dataframe**

# %%
fake_manual_testing.head(10)
# Out:
#                                                    title  \
# 23471  Seven Iranians freed in the prisoner swap have...
# 23472                      #Hashtag Hell & The Fake Left
# 23473  Astroturfing: Journalist Reveals Brainwashing ...
# 23474          The New American Century: An Era of Fraud
# 23475  Hillary Clinton: ‘Israel First’ (and no peace ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 23471  21st Century Wire says This week, the historic...  Middle-east
# 23472   By Dady Chery and Gilbert MercierAll writers ...  Middle-east
# 23473  Vic Bishop Waking TimesOur reality is carefull...  Middle-east
# ...

# %%
true_manual_testing.head(10)
# Out:
#                                                    title  \
# 21407  Mata Pires, owner of embattled Brazil builder ...
# 21408  U.S., North Korea clash at U.N. forum over nuc...
# 21409  U.S., North Korea clash at U.N. arms forum on ...
# 21410  Headless torso could belong to submarine journ...
# 21411  North Korea shipments to Syria chemical arms a...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21407  SAO PAULO (Reuters) - Cesar Mata Pires, the ow...  worldnews
# 21408  GENEVA (Reuters) - North Korea and the United ...  worldnews
# 21409  GENEVA (Reuters) - North Korea and the United ...  worldnews
# ...

# %% [markdown]
# **Merging the two dataframes**

# %%
merge=pd.concat([fake,true],axis=0)

# %% [markdown]
# **Taking a sneak peek into the merged dataframe**

# %%
merge.head(10)
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
# 5   Racist Alabama Cops Brutalize Black Boy While...
# 6   Fresh Off The Golf Course, Trump Lashes Out A...
# 7   Trump Said Some INSANELY Racist Stuff Inside ...
# 8   Former CIA Director Slams Trump Over UN Bully...
# 9   WATCH: Brand-New Pro-Trump Ad Features So Muc...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
# ...

# %% [markdown]
# **Columns in the merged Dataframe**

# %%
merge.columns
# Out:
# Index(['title', 'text', 'subject', 'date', 'class'], dtype='object')

# %% [markdown]
# **Dropping the unnecessary columns **

# %%
data=merge.drop(['title','subject','date'],axis=1)

# %% [markdown]
# **Checking for the Null Values**

# %%
data.isnull().sum()
# Out:
# text     0
# class    0
# dtype: int64

# %%
data=data.sample(frac=1)

# %%
data.head()
# Out:
#                                                     text  class
# 18891  A long-time aide to Hillary Clinton sought to ...      0
# 9198   WASHINGTON (Reuters) - U.S. Senator Elizabeth ...      1
# 17991  WFB- The former Democratic presidential candid...      0
# 8441   WASHINGTON/PHILADELPHIA (Reuters) - Hillary Cl...      1
# 11726  Protesters decrying President Donald Trump s t...      0

# %% [markdown]
# **Resetting the index of the Dataframe**

# %%
data.reset_index(inplace=True)

# %%
data.drop(['index'],axis=1,inplace=True)

# %% [markdown]
# Columns of the dataframe

# %%
data.columns
# Out:
# Index(['text', 'class'], dtype='object')

# %%
data.head()
# Out:
#                                                 text  class
# 0  A long-time aide to Hillary Clinton sought to ...      0
# 1  WASHINGTON (Reuters) - U.S. Senator Elizabeth ...      1
# 2  WFB- The former Democratic presidential candid...      0
# 3  WASHINGTON/PHILADELPHIA (Reuters) - Hillary Cl...      1
# 4  Protesters decrying President Donald Trump s t...      0

# %%
def wordopt(text):
  text=re.sub('\[.*?/]','',text)
  text=re.sub('\\W'," ",text)
  text=re.sub("https?://\S+/www.\S+",'',text)
  text=re.sub('<.*?>+','',text)
  text=re.sub('[%s]'%re.escape(string.punctuation),'',text)
  text=re.sub('\n','',text)
  text=re.sub('\w*\d\w*','',text)
  return text
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\['
# <>:4: SyntaxWarning: invalid escape sequence '\S'
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# <>:2: SyntaxWarning: invalid escape sequence '\['
# <>:4: SyntaxWarning: invalid escape sequence '\S'
# <>:8: SyntaxWarning: invalid escape sequence '\w'
# /tmp/ipython-input-2510256383.py:2: SyntaxWarning: invalid escape sequence '\['
#   text=re.sub('\[.*?/]','',text)
# /tmp/ipython-input-2510256383.py:4: SyntaxWarning: invalid escape sequence '\S'
#   text=re.sub("https?://\S+/www.\S+",'',text)
# /tmp/ipython-input-2510256383.py:8: SyntaxWarning: invalid escape sequence '\w'
#   text=re.sub('\w*\d\w*','',text)

# %%
data['text']=data['text'].apply(wordopt)

# %%
x=data['text']
y=data['class']

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorization=TfidfVectorizer()
xv_train=vectorization.fit_transform(x_train)
xv_test=vectorization.transform(x_test)

# %% [markdown]
# **Logistic Regression Algorithm**

# %%
from sklearn.linear_model import LogisticRegression
LR=LogisticRegression()
LR.fit(xv_train,y_train)
# Out:
# LogisticRegression()

# %%
pred_lr=LR.predict(xv_test)

# %%
LR.score(xv_test,y_test)
# Out:
# 0.9877896613190731

# %%
print(classification_report(y_test,pred_lr))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.98      0.99      5878
#            1       0.98      0.99      0.99      5342
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %% [markdown]
# **Decision Tree Classifier Algorithm**

# %%
from sklearn.tree import DecisionTreeClassifier
DT=DecisionTreeClassifier()
DT.fit(xv_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dt=DT.predict(xv_test)

# %%
DT.score(xv_test,y_test)
# Out:
# 0.9952762923351158

# %%
print(classification_report(y_test,pred_dt))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      1.00      5878
#            1       1.00      0.99      1.00      5342
#
#     accuracy                           1.00     11220
#    macro avg       1.00      1.00      1.00     11220
# weighted avg       1.00      1.00      1.00     11220

# %% [markdown]
# **Gradient Boosting Algorithm**

# %%
from sklearn.ensemble import GradientBoostingClassifier
GB=GradientBoostingClassifier( random_state=0)
GB.fit(xv_train,y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
pred_gb=GB.predict(xv_test)

# %%
GB.score(xv_test,y_test)
# Out:
# 0.9946524064171123

# %%
print(classification_report(y_test,pred_gb))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99      5878
#            1       0.99      1.00      0.99      5342
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %% [markdown]
# **Random Forest Classifier**

# %%
from sklearn.ensemble import RandomForestClassifier
RF=RandomForestClassifier(random_state=0)
RF.fit(xv_train,y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %%
pred_rf=RF.predict(xv_test)

# %%
RF.score(xv_test,y_test)
# Out:
# 0.9908199643493761

# %%
print(classification_report(y_test,pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      5878
#            1       0.99      0.99      0.99      5342
#
#     accuracy                           0.99     11220
#    macro avg       0.99      0.99      0.99     11220
# weighted avg       0.99      0.99      0.99     11220

# %% [markdown]
# **Testing and predicting the model**

# %%
def output_label(n):
  if n==0:
    return "Fake news"
  elif n==1:
    return "Not a Fake news"

# %%
def manual_testing(news):
  testing_news={"text":[news]}
  new_def_test=pd.DataFrame(testing_news)
  new_def_test["text"]=new_def_test["text"].apply(wordopt)
  new_x_test=new_def_test["text"]
  new_xv_test=vectorization.transform(new_x_test)
  pred_LR=LR.predict(new_xv_test)
  pred_DT=DT.predict(new_xv_test)
  pred_GB=GB.predict(new_xv_test)
  pred_RF=RF.predict(new_xv_test)
  return print("\n\nLR Prediction: {} \nDT Prediction: {} \nGB Prediction: {} \nRF Prediction: {}".format(output_label(pred_LR[0]),output_label(pred_DT[0]),output_label(pred_GB[0]),output_label(pred_RF[0])))

# %% [markdown]
# **Input the news and Checking for it**

# %%
news=str(input())
manual_testing(news)
# Out:
# After Pakistan and Afghanistan resumed attacks following a brief 48 hour truce, Qatar has confirmed that both nations have agreed to a "immediate ceasefire' on Saturday. The latest truce was brokered by Qatar and Turkey.  As per the official statement from the Qatari foreign affairs ministry, both Afghanistan and Pakistan have also agreed to hold follow up meetings in the coming days "to ensure sustainability of the ceasefire and verify its implementation in a reliable and sustainable manner, thus contributing to achieving security and stability in both countries."
#
#
# LR Prediction: Not a Fake news
# DT Prediction: Fake news
# GB Prediction: Fake news
# RF Prediction: Not a Fake news

# %%
news=str(input())
manual_testing(news)
# Out:
# A leaked 27‑minute audio recording allegedly captures opposition party leader Tomas Redding negotiating a multi‑million dollar bribe with business executives, sources say. The tape was posted to an obscure file‑sharing site this morning and quickly circulated on encrypted messaging apps. Redding was arrested at 9 a.m. local time after a brief courthouse hearing; police say the recording sparked a formal corruption probe. Redding’s spokesperson called the tape “doctored and politically motivated.” Investigators declined to confirm the recording’s authenticity while vowing a full inquiry. The alleged bribe involves an infrastructure contract for the Riverway Bridge, which critics say was awarded under suspicious circumstances last year.
#
#
# LR Prediction: Fake news
# DT Prediction: Fake news
# GB Prediction: Fake news
# RF Prediction: Fake news

# %%
news=str(input())
manual_testing(news)
# Out:
# The International Monetary Fund (IMF) has revised India’s economic growth forecast for the fiscal year 2025–26, raising it to 6.6% despite ongoing trade tensions and new U.S. tariffs on Indian exports. The IMF attributes the upward revision to stronger-than-expected private consumption and resilient domestic demand. While the forecast for 2026–27 was slightly lowered to 6.2%, analysts note that India’s economy continues to show robustness compared to other major emerging markets. The IMF’s October report also acknowledged India’s progress on inflation management and fiscal consolidation efforts.
#
#
# LR Prediction: Fake news
# DT Prediction: Fake news
# GB Prediction: Fake news
# RF Prediction: Not a Fake news

# %%
news=str(input())
manual_testing(news)
# Out:
# Ayodhya is gearing up to celebrate Deepotsav 2025 by lighting an estimated 2.61 million earthen lamps (diyas) along the banks of the Sarayu River on October 19th. The local government is aiming to set a new Guinness World Record for the highest number of diyas lit at a single venue. The annual festival, which celebrates the return of Lord Rama to Ayodhya, has grown significantly in scale and global attention in recent years. Officials are coordinating with volunteers, artisans, and event organizers to ensure smooth execution and safety during the massive lighting ceremony.
#
#
# LR Prediction: Fake news
# DT Prediction: Fake news
# GB Prediction: Fake news
# RF Prediction: Fake news

# %%
news=str(input())
manual_testing(news)
# Out:
# WASHINGTON (Reuters) - The U.S. Senate Banking Committee rejected U.S. President Donald Trumpâ€™s nominee to head the U.S. Export-Import Bank on Tuesday  but approved four other board nominees, enough to restore the trade bankâ€™s full lending powers upon their confirmation by the full Senate. The committee voted 13-10 against Scott Garrett as EXIM president in a rebuke to conservatives who saw the former New Jersey Republican congressman as an ally who would keep tight controls on the government export lender.  Garrett helped lead a 2015 effort to shut down EXIM to end a source of â€œcorporate welfareâ€ for giant manufacturers such as Boeing Co and General Electric. After his nomination he pledged to keep the bank â€œfully openâ€ but struggled to persuade senators that he now believed in the bankâ€™s core mission of providing taxpayer-backed loans and guarantees for U.S. export transactions. â€œI believe heâ€™s a principled man who simply believes in the abolishment of the bank,â€
# ...

# %%
news=str(input())
manual_testing(news)
# Out:
# Researchers at the privately funded Novara Institute report a pill that reportedly induced complete remission in 18 of 18 trial participants with Type 2 diabetes within six weeks. The institute claims the compound, NV‑17, targets a previously unknown metabolic pathway and restores insulin sensitivity. Lead researcher Dr. Hakeem Salim described the results as “unprecedented.” Novara plans to start expanded trials later this year and has already applied for emergency approval in several countries. Some independent scientists caution the trial size is too small to draw conclusions; patient records and methodology have not yet been released.
#
#
# LR Prediction: Fake news
# DT Prediction: Fake news
# GB Prediction: Fake news
# RF Prediction: Fake news

# %%
news=str(input())
manual_testing(news)
# Out:
# The US State Department says it has "credible reports" that Hamas is planning an "imminent" attack on civilians in Gaza, which it says would violate the ceasefire agreement.  A statement released on Saturday said a planned attack against Palestinians would be a "direct and grave" violation of the ceasefire agreement and "undermine the significant progress achieved through mediation efforts".  The state department did not not provide further details on the attack and it is unclear what reports it was citing.  The first phase of the ceasefire deal between Hamas and Israel is currently in progress - all living hostages have been released and bodies of the deceased are still being returned to Israel.
#
#
# LR Prediction: Fake news
# DT Prediction: Fake news
# GB Prediction: Fake news
# RF Prediction: Not a Fake news

# %%
news=str(input())
manual_testing(news)
# Out:
# EW YORK (Reuters) - The U.S. Justice Department has issued new guidelines for immigration judges that remove some instructions for how to protect unaccompanied juveniles appearing in their courtrooms. A Dec. 20 memo, issued by the Executive Office for Immigration Review (EOIR) replaces 2007 guidelines, spelling out policies and procedures judges should follow in dealing with children who crossed the border illegally alone and face possible deportation.  The new memo removes suggestions contained in the 2007 memo for how to conduct â€œchild-sensitive questioningâ€ and adds reminders to judges to maintain â€œimpartialityâ€ even though â€œjuvenile cases may present sympathetic allegations.â€ The new document also changes the word â€œchildâ€ to â€œunmarried individual under the age of 18â€ in many instances. (Link to comparison: tmsnrt.rs/2BlT0VK May 2007 document: tmsnrt.rs/2BBR8wj December 2017 document: tmsnrt.rs/2C2sWCs)  An EOIR official said the new memo contained â€œclarifica
# ...

# %%
news=str(input())
manual_testing(news)
# Out:
# It almost seems like Donald Trump is trolling America at this point. In the beginning, when he tried to gaslight the country by insisting that the crowd at his inauguration was the biggest ever   or that it was even close to the last couple of inaugurations   we all kind of scratched our heads and wondered what kind of bullshit he was playing at. Then when he started appointing people to positions they had no business being in, we started to worry that this was going to go much worse than we had expected.After 11 months of Donald Trump pulling the rhetorical equivalent of whipping his dick out and slapping it on every table he gets near, I think it s time we address what s happening: Dude is a straight-up troll. He gets pleasure out of making other people uncomfortable or even seeing them in distress. He actively thinks up ways to piss off people he doesn t like.Let s set aside just for a moment the fact that that s the least presidential  behavior anyone s ever heard of   it s dange
# ...

# %%
news=str(input())
manual_testing(news)
# Out:
# WASHINGTON (Reuters) - A U.S. District Court judge on Friday said she would release former Trump campaign manager Paul Manafort from house arrest once he meets certain conditions, expressing satisfaction that the $10 million he agreed to forfeit would be available if he ever failed to appear for court proceedings. In her order, Judge Amy Berman Jackson said to be released from home confinement, Manafort must execute documents agreeing to forfeit four properties, including two in New York, one in Alexandria, Virginia, and his Florida home.    He will be subject to restrictions including a curfew and electronic GPS monitoring but will be allowed to leave his home in Alexandria for his home in Palm Beach Gardens, Florida, once he meets the conditions.  Manafort is charged with conspiring to launder money and failing to register as a foreign agent working on behalf of the government of Ukraineâ€™s former pro-Russia President Viktor Yanukovych.  He is being prosecuted by Special Counsel R
# ...

# %% [markdown]
# **Conclusion**

# %% [markdown]
# The Fake News Detection System helps identify and prevent the spread of false information using machine learning and natural language processing. It analyzes news content to classify it as real or fake with high accuracy. This system promotes truthful information sharing and helps users make informed decisions. Though effective, it can be improved by adding deep learning and real-time verification features. Overall, it contributes to creating a safer and more reliable digital information space.
